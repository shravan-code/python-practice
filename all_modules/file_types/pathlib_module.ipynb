# %% [markdown]
# # pathlib module
#
# The pathlib module provides an object-oriented interface for filesystem paths. It replaces many use cases of os.path with a cleaner, more readable, and more Pythonic API.
#
# **Introduced in Python 3.4, pathlib is now the recommended way to handle paths in modern Python.**

# %%
import os

path = os.path.join("all_modules", "file_types", "pathlib_module.ipynb")
if os.path.exists(path):
    print(os.path.abspath(path))
path
# Out:
# 'all_modules\\file_types\\pathlib_module.ipynb'

# %%
import pathlib

# %%
print(dir(pathlib))
# Out:
# ['DirEntryInfo', 'E2BIG', 'EACCES', 'EADDRINUSE', 'EADDRNOTAVAIL', 'EAFNOSUPPORT', 'EAGAIN', 'EALREADY', 'EBADF', 'EBADMSG', 'EBUSY', 'ECANCELED', 'ECHILD', 'ECONNABORTED', 'ECONNREFUSED', 'ECONNRESET', 'EDEADLK', 'EDEADLOCK', 'EDESTADDRREQ', 'EDOM', 'EDQUOT', 'EEXIST', 'EFAULT', 'EFBIG', 'EHOSTDOWN', 'EHOSTUNREACH', 'EIDRM', 'EILSEQ', 'EINPROGRESS', 'EINTR', 'EINVAL', 'EIO', 'EISCONN', 'EISDIR', 'ELOOP', 'EMFILE', 'EMLINK', 'EMSGSIZE', 'ENAMETOOLONG', 'ENETDOWN', 'ENETRESET', 'ENETUNREACH', 'ENFILE', 'ENOBUFS', 'ENODATA', 'ENODEV', 'ENOENT', 'ENOEXEC', 'ENOLCK', 'ENOLINK', 'ENOMEM', 'ENOMSG', 'ENOPROTOOPT', 'ENOSPC', 'ENOSR', 'ENOSTR', 'ENOSYS', 'ENOTCONN', 'ENOTDIR', 'ENOTEMPTY', 'ENOTRECOVERABLE', 'ENOTSOCK', 'ENOTSUP', 'ENOTTY', 'ENXIO', 'EOPNOTSUPP', 'EOVERFLOW', 'EOWNERDEAD', 'EPERM', 'EPFNOSUPPORT', 'EPIPE', 'EPROTO', 'EPROTONOSUPPORT', 'EPROTOTYPE', 'ERANGE', 'EREMOTE', 'EROFS', 'ESHUTDOWN', 'ESOCKTNOSUPPORT', 'ESPIPE', 'ESRCH', 'ESTALE', 'ETIME', 'ETIMEDOUT', 'ETOOMANYREFS', 'ETXTBSY', 'EUSERS', 'EWOULDBLOCK', 'EXDEV', 'Path', 'PathInfo', 'PosixPath', 'PurePath', 'PurePosixPath', 'PureWindowsPath', 'S_ISBLK', 'S_ISCHR', 'S_ISDIR', 'S_ISFIFO', 'S_ISREG', 'S_ISSOCK', 'Sequence', 'UnsupportedOperation', 'WSABASEERR', 'WSAEACCES', 'WSAEADDRINUSE', 'WSAEADDRNOTAVAIL', 'WSAEAFNOSUPPORT', 'WSAEALREADY', 'WSAEBADF', 'WSAECONNABORTED', 'WSAECONNREFUSED', 'WSAECONNRESET', 'WSAEDESTADDRREQ', 'WSAEDISCON', 'WSAEDQUOT', 'WSAEFAULT', 'WSAEHOSTDOWN', 'WSAEHOSTUNREACH', 'WSAEINPROGRESS', 'WSAEINTR', 'WSAEINVAL', 'WSAEISCONN', 'WSAELOOP', 'WSAEMFILE', 'WSAEMSGSIZE', 'WSAENAMETOOLONG', 'WSAENETDOWN', 'WSAENETRESET', 'WSAENETUNREACH', 'WSAENOBUFS', 'WSAENOPROTOOPT', 'WSAENOTCONN', 'WSAENOTEMPTY', 'WSAENOTSOCK', 'WSAEOPNOTSUPP', 'WSAEPFNOSUPPORT', 'WSAEPROCLIM', 'WSAEPROTONOSUPPORT', 'WSAEPROTOTYPE', 'WSAEREMOTE', 'WSAESHUTDOWN', 'WSAESOCKTNOSUPPORT', 'WSAESTALE', 'WSAETIMEDOUT', 'WSAETOOMANYREFS', 'WSAEUSERS', 'WSAEWOULDBLOCK', 'WSANOTINITIALISED', 'WSASYSNOTREADY', 'WSAVERNOTSUPPORTED', 'WindowsPath', '_PathParents', '_StringGlobber', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_no_recurse_symlinks', '_os', 'chain', 'copy_info', 'copyfile2', 'copyfileobj', 'ensure_different_files', 'ensure_distinct_paths', 'errorcode', 'grp', 'io', 'magic_open', 'ntpath', 'operator', 'os', 'posixpath', 'pwd', 'sys']

# %%
path = pathlib.Path("all_modules") / "file_types" / "pathlib_module.ipynb"
if path.exists():
    print(path.resolve())

path
# Out:
# WindowsPath('all_modules/file_types/pathlib_module.ipynb')

# %%
type(path)
# Out:
# pathlib.WindowsPath

# %%
p = pathlib.PurePath("all_modules") / "file_types"
p.parent, p.parents
# Out:
# (PureWindowsPath('all_modules'), <PureWindowsPath.parents>)

# %%
p1 = pathlib.Path("file.txt")
p2 = pathlib.Path("/usr/local/bin")
p3 = pathlib.Path.home()
p4 = pathlib.Path.cwd()

p4
# Out:
# WindowsPath('D:/shra1/github/python-practice/all_modules/file_types')

# %%
p = pathlib.Path(r"D:\shra1\github\python-practice\all_modules\file_types\pathlib_module.ipynb")

p.name, p.stem, p.suffix, p.suffixes, p.parent  # all ancestors
# Out:
# ('pathlib_module.ipynb',
#  'pathlib_module',
#  '.ipynb',
#  ['.ipynb'],
#  WindowsPath('D:/shra1/github/python-practice/all_modules/file_types'))

# %%
list(p.parents)
# Out:
# [WindowsPath('D:/shra1/github/python-practice/all_modules/file_types'),
#  WindowsPath('D:/shra1/github/python-practice/all_modules'),
#  WindowsPath('D:/shra1/github/python-practice'),
#  WindowsPath('D:/shra1/github'),
#  WindowsPath('D:/shra1'),
#  WindowsPath('D:/')]

# %%
p.exists(), p.is_file(), p.is_dir(), p.is_symlink()
# Out:
# (True, True, False, False)

# %%
p = pathlib.Path("example.txt")

p.write_text("Hello, Shravan")
content = p.read_text()
content
# Out:
# 'Hello, Shravan'

# %%
with pathlib.Path("example.txt").open("r") as f:
    print(f.read())
# Out:
# Hello, Shravan

# %%
pathlib.Path('new_folder').mkdir()  # creates directory

# %%
pathlib.Path("new_folder").rmdir()  # deletes directory

# %%
pathlib.Path('example.txt').unlink()

# %% [markdown]
# | Feature        | `os.path`        | `pathlib`       |
# | -------------- | ---------------- | --------------- |
# | Style          | Functional       | Object-oriented |
# | Readability    | Moderate         | High            |
# | Path joining   | `os.path.join()` | `/` operator    |
# | Cross-platform | Yes              | Yes             |
# | Recommended    | Legacy           | Modern Python   |
