# %% [markdown]
# # platform module
#
# The platform module is part of Python’s standard library and provides read-only access to underlying system, OS, and hardware metadata. It is commonly used for environment detection, cross-platform compatibility logic, debugging, and runtime diagnostics.

# %% [markdown]
# **Core Use Cases**
#
# * Detect operating system and kernel
# * Identify CPU architecture
# * Determine Python implementation and version
# * Implement OS-specific branching in code
# * Capture runtime environment details for logs and support

# %%
import platform

# %%
platform.platform()
# Out:
# 'Windows-11-10.0.26200-SP0'

# %%
platform.system()
# Out:
# 'Windows'

# %%
platform.release()
# Out:
# '11'

# %%
platform.version()
# Out:
# '10.0.26200'

# %%
platform.node()
# Out:
# 'Saaho'

# %%
platform.machine()
# Out:
# 'AMD64'

# %%
platform.processor()
# Out:
# 'AMD64 Family 23 Model 96 Stepping 1, AuthenticAMD'

# %%
platform.architecture()
# Out:
# ('64bit', 'WindowsPE')

# %%
platform.python_version()
# Out:
# '3.14.2'

# %%
platform.python_implementation()
# Out:
# 'CPython'

# %%
platform.android_ver()
# Out:
# AndroidVer(release='', api_level=0, manufacturer='', model='', device='', is_emulator=False)

# %%
platform.python_compiler()
# Out:
# 'MSC v.1944 64 bit (AMD64)'

# %%
platform.python_build()
# Out:
# ('tags/v3.14.2:df79316', 'Dec  5 2025 17:18:21')
