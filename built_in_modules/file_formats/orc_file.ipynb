# %% [markdown]
# # ORC File (Optimized Row Columnar)
#
# ORC (Optimized Row Columnar) is a columnar storage file format designed for large-scale analytics. It was introduced by Apache Hive and is widely used across the Apache big data ecosystem for high-performance reads and efficient storage.
