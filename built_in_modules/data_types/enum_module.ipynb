# %% [markdown]
# **Python enum Module**
#
# The enum module (introduced in Python 3.4) provides support for creating enumerations — symbolic names bound to constant, unique values.
#
# Enumerations are used for:
# * Readability
# * Preventing invalid values
# * Creating groups of related constants
# * Enforcing immutability and identity checks

# %%
import enum

# %%
print(enum.__all__)
# Out:
# ['EnumType', 'EnumMeta', 'EnumDict', 'Enum', 'IntEnum', 'StrEnum', 'Flag', 'IntFlag', 'ReprEnum', 'auto', 'unique', 'property', 'verify', 'member', 'nonmember', 'FlagBoundary', 'STRICT', 'CONFORM', 'EJECT', 'KEEP', 'global_flag_repr', 'global_enum_repr', 'global_str', 'global_enum', 'EnumCheck', 'CONTINUOUS', 'NAMED_FLAGS', 'UNIQUE', 'pickle_by_global_name', 'pickle_by_enum_name']

# %%
class Color(enum.Enum):
    RED = 1
    GREEN = 2
    BLUE = 3
    YELLOW = 4

# %%
Color.RED.name, Color.RED.value, type(Color)
# Out:
# ('RED', 1, enum.EnumType)

# %%
Color.Red = 10
type(Color), type(Color.Red)
# Out:
# (enum.EnumType, int)

# %%
Color.Red, type(Color), type(Color.Red)
# Out:
# (10, enum.EnumType, int)

# %%
 #TODO need to add more examples and explanations about enum module
